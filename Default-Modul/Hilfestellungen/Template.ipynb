# %% [markdown]
# Zuerst sollten alle benötigten Pakete importiert werden. Diese beinhalten unter anderem:
# NumPy
# UNumPy
# PyPlot von MatPlotLib
# SciPy

# %%
# Hier werden die Pakete importiert:

# import Paket as Alias

# %% [markdown]
# Nun müssen die Daten eingelesen werden. Hierfür sollten diese als csv oder einer anderen Art von Textdatei vorliegen.

# %%
# Messdaten einlesen:

# a, b, c = np.loadtxt('data.txt', unpack=True, delimiter=',')

# %% [markdown]
# Zur fortpflanzung die Arrays in UNumPy Arrays umändern.

# %%
# Hier werden die Messdaten zur weiteren verwendung in UNumPy Arrays umgewandelt:

# ZeitMitUnsicherheiten = unp.uarray(t, dt)

# %% [markdown]
# Nun werden die Messdaten das erste Mal geplottet. Für manche Berichte müssen die verschiedenen Messwerte vorher noch miteinander verrechnet werden.

# %%
# PLot der Daten:

# plt.errorbar(x, y, xerr=dx, yerr=dy, fmt='o', label='Messdaten', color='blue', ecolor='red', elinewidth=1, capsize=3)
# plt.xlabel('x-Achse')
# plt.ylabel('y-Achse')
# plt.title('Titel des Plots')
# plt.legend()

# %% [markdown]
# Als nächste kann mit polyfit von NumPy oder besser noch mit ODR von SciPy eine Funktion gefittet werden. Oft reicht hier die Lineare Regression aus.

# %%
# Fitten einer geigneten Funktion mit ODR:

# Parameterabhängige Funktion f definieren
# ODR Model erstellen
# Daten in ODR Format bringen
# ODR Fit durchführen
# Parameter und Unsicherheiten (Diagonale von Matrix) extrahieren

# %% [markdown]
# Nun die Funktion wieder Plotten

# %%
# Plot der Annäherung mit Unsicherheiten:

# Zeit = np.linspace(t[0], t[-1], 100)
# plt.errorbar(x, y, xerr=dx, yerr=dy, fmt='o', label='Messdaten', color='blue', ecolor='red', elinewidth=1, capsize=3)
# plt.plot(Zeit, f(Zeit), label='Fit', color='green')
# plt.plot(Zeit, f(Zeit) + unp.std_devs(f(Zeit)), 'r--', label='Unsicherheiten')
# plt.plot(Zeit, f(Zeit) - unp.std_devs(f(Zeit)), 'r--', label='Unsicherheiten')
# plt.xlabel('x-Achse')
# plt.ylabel('y-Achse')
# plt.title('Titel des Plots')
# plt.legend()
